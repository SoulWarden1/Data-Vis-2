# %%
import pandas as pd

# %%
trips = pd.read_csv("data/vista_trips_2023-2025.csv")
trips = trips[["year","origlga","destplace1","destplace2","destpurp1","destpurp2","destlga","triptime","cumdist"]]
trips = trips[(trips["year"] >= 2022) & (trips["destplace2"] == "Restaurant or Cafe") & (trips["destpurp2"] == "Ate or drank") & (trips["origlga"].str.endswith(" (C)"))]
trips = trips[~trips["origlga"].isin(["Warrnambool (C)", "Ballarat (C)", "Greater Geelong (C)", "Greater Bendigo (C)", "Greater Shepparton (C)"])]

trips["cumdist"] = pd.to_numeric(trips["cumdist"], errors="coerce")
trips["triptime"] = pd.to_numeric(trips["triptime"], errors="coerce")

trips["origlga"] = trips["origlga"].str.replace(" (C)", "", regex=False)
trips
# Out:
# C:\Users\Ryan\AppData\Local\Temp\ipykernel_13084\66097770.py:1: DtypeWarning: Columns (0: triptime, 1: travtime, 2: time1) have mixed types. Specify dtype option on import or set low_memory=False.
#   trips = pd.read_csv("data/vista_trips_2023-2025.csv")
#        year            origlga           destplace1          destplace2  \
# 4      2024  Greater Dandenong  Entertainment venue  Restaurant or Cafe
# 63     2024  Greater Dandenong  Entertainment venue  Restaurant or Cafe
# 297    2024              Yarra  Entertainment venue  Restaurant or Cafe
# 302    2024         Whittlesea  Entertainment venue  Restaurant or Cafe
# 314    2024         Whittlesea  Entertainment venue  Restaurant or Cafe
# ...     ...                ...                  ...                 ...
# 70691  2022               Knox  Entertainment venue  Restaurant or Cafe
# 70755  2022               Knox  Entertainment venue  Restaurant or Cafe
# 70763  2022               Knox  Entertainment venue  Restaurant or Cafe
# 70977  2022         Boroondara  Entertainment venue  Restaurant or Cafe
# 71017  2022         Boroondara  Entertainment venue  Restaurant or Cafe
#
#       destpurp1     destpurp2                destlga  triptime   cumdist
# 4        Social  Ate or drank  Greater Dandenong (C)        10   5.06795
# 63       Social  Ate or drank  Greater Dandenong (C)         3   1.12386
# 297      Social  Ate or drank          Nillumbik (S)        25  24.18257
# 302      Social  Ate or drank         Whittlesea (C)         2   0.55836
# 314      Social  Ate or drank         Whittlesea (C)         2   0.55836
# ...         ...           ...                    ...       ...       ...
# 70691    Social  Ate or drank               Knox (C)         3   1.78371
# 70755    Social  Ate or drank               Knox (C)        10   1.79484
# 70763    Social  Ate or drank               Knox (C)         2   0.05062
# 70977    Social  Ate or drank          Melbourne (C)        50  13.89169
# 71017    Social  Ate or drank         Boroondara (C)         5   0.36603
#
# [1478 rows x 9 columns]

# %%
cafe_trips = trips[["origlga","triptime","cumdist"]].groupby("origlga").mean()
cafe_trips = cafe_trips.sort_values("cumdist").reset_index()
cafe_trips.to_csv("data/cafe_trips_by_lga.csv", index=False)
cafe_trips
# Out:
#               origlga   triptime    cumdist
# 0               Yarra  11.222222   2.298213
# 1           Melbourne  14.836364   2.639538
# 2          Manningham  13.584906   4.072022
# 3       Moonee Valley  16.884615   4.082673
# 4         Stonnington  13.763636   4.280057
# 5          Boroondara  16.961039   4.845324
# 6        Port Phillip  14.807018   5.003441
# 7            Brimbank  14.000000   5.398371
# 8           Frankston  10.342857   5.467368
# 9             Banyule  18.480769   6.143856
# 10            Darebin  18.375000   6.429556
# 11  Greater Dandenong  13.178571   6.435045
# 12        Hobsons Bay  16.794872   6.908007
# 13             Monash  16.764706   7.140221
# 14         Whitehorse  15.253521   7.230880
# 15               Knox  13.590164   7.282852
# 16        Maribyrnong  16.928571   7.451928
# 17          Merri-bek  18.313433   7.535249
# 18          Glen Eira  18.277778   7.690508
# 19           Kingston  17.235294   8.332665
# 20          Maroondah  15.050000   9.977709
# 21            Bayside  21.596774  10.010844
# 22               Hume  16.058824  12.713386
# 23         Whittlesea  23.523810  14.083546
# 24            Wyndham  27.925000  15.510706
# 25              Casey  31.675000  22.286455
